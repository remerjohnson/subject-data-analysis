# %% [markdown]
# # Subject Conversion data work with `pandas`
#
# This is a notebook to work with our subject reconciliation data and start to analyze it a bit. Maybe clean it in certain ways, too.

# %%
import pandas as pd

# %% [markdown]
# After we get pandas set up, let's first see if the data is ready:

# %%
# !head subj_conv.csv
# Out:
# Status,DAMS_ARK,New Predicate,Clean_Label (used for reconciliation can probably be deleted),Action,clustering label,clustering id,MARC_tag,Sample_Object_ARK,Object_Counts
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb11618059,not a subject,1936,Omit,,,,http://library.ucsd.edu/dc/object/bb0000817g,2
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb8738666t,not a subject,1936,Omit,,,,http://library.ucsd.edu/dc/object/bb96937381,1
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb30389577,not a subject,1938,Omit,,,,http://library.ucsd.edu/dc/object/bb06157271,1
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb4881974q,not a subject,1938,Omit,,,,http://library.ucsd.edu/dc/object/bb96596041,97
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb5530534z,dams:topic,??? ? (Motion picture),Local,,,,http://library.ucsd.edu/dc/object/bb4540465j,1
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb6656819t,Work title!,??? ?? (Motion picture),character problem,,,,http://library.ucsd.edu/dc/object/bb3277655n,1
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb4574893j,Work title!,??? ?? (Opera),Omit,,,,http://library.ucsd.edu/dc/object/bb55302375,1
# split from complex no match,http://library.ucsd.edu/ark:/20775/bb48479934,not a subject,1556-1648,Omit,,,,http://library.ucsd.edu/dc/object/bb90801264,2
# split from complex matched FAST,http://library.ucsd.edu/ark:/20775/bb61449336,dams:topic,1621-1665,FAST,Thirty Years' War (1618-1648),http://id.worldcat.org/fast/1150141,148,http://library.ucsd.edu/dc/object/bb90801264,2

# %% [markdown]
# Now let's get `pandas` to get this as a dataframe and show us a snippet. We'll use the magic `%%time` which will tell us how quickly this large-ish (>3MB) csv will become a dataframe

# %%
# %%time

df = pd.read_csv('subj_conv.csv')
# Out:
# CPU times: user 68 ms, sys: 32 ms, total: 100 ms
# Wall time: 118 ms

# %% [markdown]
# Now let's look at a little snippet at the beginning of the data

# %%
df.head()
# Out:
#                         Status                                       DAMS_ARK  \
# 0  split from complex no match  http://library.ucsd.edu/ark:/20775/bb11618059
# 1  split from complex no match  http://library.ucsd.edu/ark:/20775/bb8738666t
# 2  split from complex no match  http://library.ucsd.edu/ark:/20775/bb30389577
# 3  split from complex no match  http://library.ucsd.edu/ark:/20775/bb4881974q
# 4  split from complex no match  http://library.ucsd.edu/ark:/20775/bb5530534z
#
#    New Predicate  \
# 0  not a subject
# 1  not a subject
# 2  not a subject
# 3  not a subject
# 4     dams:topic
#
#   Clean_Label (used for reconciliation can probably be deleted) Action  \
# 0                                               1936              Omit
# 1                                               1936              Omit
# 2                                               1938              Omit
# 3                                               1938              Omit
# 4                             ??? ? (Motion picture)             Local
#
#   clustering label clustering id  MARC_tag  \
# 0              NaN           NaN       NaN
# 1              NaN           NaN       NaN
# 2              NaN           NaN       NaN
# 3              NaN           NaN       NaN
# 4              NaN           NaN       NaN
#
#                               Sample_Object_ARK  Object_Counts
# 0  http://library.ucsd.edu/dc/object/bb0000817g            2.0
# 1  http://library.ucsd.edu/dc/object/bb96937381            1.0
# 2  http://library.ucsd.edu/dc/object/bb06157271            1.0
# 3  http://library.ucsd.edu/dc/object/bb96596041           97.0
# 4  http://library.ucsd.edu/dc/object/bb4540465j            1.0

# %% [markdown]
# Since we only looked at the head of the doc, you might start to think our MARC tags and clustered labels/URIs are blank. Let's slice down a little further (row 196-206) in the data and see what's going on

# %%
df[195:205]
# Out:
#                           Status  \
# 195        original matched FAST
# 196            original no match
# 197  split from complex no match
# 198            original no match
# 199            original no match
# 200        original matched FAST
# 201        original matched FAST
# 202        original matched FAST
# 203        original matched FAST
# 204        original matched FAST
#
#                                           DAMS_ARK      New Predicate  \
# 195  http://library.ucsd.edu/ark:/20775/bb7612563x         dams:topic
# 196  http://library.ucsd.edu/ark:/20775/bb1605629j    dams:familyName
# 197  http://library.ucsd.edu/ark:/20775/bb2902566k  dams:personalName
# 198  http://library.ucsd.edu/ark:/20775/bb3004897x  dams:personalName
# 199  http://library.ucsd.edu/ark:/20775/bb34827930    dams:geographic
# 200  http://library.ucsd.edu/ark:/20775/bb10936140         dams:topic
# 201  http://library.ucsd.edu/ark:/20775/bb9830906m         dams:topic
# 202  http://library.ucsd.edu/ark:/20775/bb1844539c    dams:geographic
# 203  http://library.ucsd.edu/ark:/20775/bb8670394r  dams:personalName
# 204  http://library.ucsd.edu/ark:/20775/bb76808298         dams:topic
#
#     Clean_Label (used for reconciliation can probably be deleted) Action  \
# 195                                     adaptive reuse              FAST
# 196                                       Addis family             Local
# 197                          Addis, Mary E., 1877-1971             Local
# 198                                Addison, Michael C.             Local
# 199                  Adelbert Range (Papua New Guinea)             Local
# 200                                     Adélie penguin              FAST
# 201                       Adélie penguin--Reproduction              FAST
# 202                                               Aden               LoC
# 203                        Adenauer, Konrad, 1876-1967              VIAF
# 204                                  Adirondack chairs              FAST
#
#                         clustering label  \
# 195  Buildings--Remodeling for other use
# 196                         Addis family
# 197            Addis, Mary E., 1877-1971
# 198                  Addison, Michael C.
# 199    Adelbert Range (Papua New Guinea)
# 200                      Adélie penguin
# 201        Adélie penguin--Reproduction
# 202                                 Aden
# 203          Adenauer, Konrad, 1876-1967
# 204                    Adirondack chairs
#
#                                      clustering id  MARC_tag  \
# 195             http://id.worldcat.org/fast/841127     150.0
# 196                                            NaN       NaN
# 197                                            NaN       NaN
# 198                                            NaN       NaN
# 199                                            NaN       NaN
# 200             http://id.worldcat.org/fast/798006     150.0
# 201             http://id.worldcat.org/fast/798008     150.0
# 202  http://id.loc.gov/authorities/names/n81053404     151.0
# 203                  http://viaf.org/viaf/34470968     100.0
# 204            http://id.worldcat.org/fast/1896314     150.0
#
#                                 Sample_Object_ARK  Object_Counts
# 195  http://library.ucsd.edu/dc/object/bb77490894           56.0
# 196  http://library.ucsd.edu/dc/object/bb3243487f            1.0
# 197  http://library.ucsd.edu/dc/object/bb3243487f            1.0
# 198  http://library.ucsd.edu/dc/object/bb9079581k            7.0
# 199  http://library.ucsd.edu/dc/object/bb0137967q           28.0
# 200  http://library.ucsd.edu/dc/object/bb3891815z            4.0
# 201  http://library.ucsd.edu/dc/object/bb90113148            1.0
# 202  http://library.ucsd.edu/dc/object/bb39602351            1.0
# 203  http://library.ucsd.edu/dc/object/bb8532501q            1.0
# 204  http://library.ucsd.edu/dc/object/bb2493068g            6.0
